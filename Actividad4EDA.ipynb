# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 4**
# Exploración de datos
#
# ---

# %% [markdown]
# *   NOMBRE: Angel Irwin Briseno Fierro
# *   MATRÍCULA: A01796844

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
#DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 4/Actividad4_EDA"
DIR = '/content/drive/MyDrive/CienciayAnaliticadeDatos_Datos'
os.chdir(DIR)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("credit_risk_dataset.csv")
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %% [markdown]
# # **Parte 1**. Análisis descriptivo (univariante)

# %% [markdown]
# 1. Utiliza el método `info()` del dataframe, para obtener el resumen de los tipos de datos. ¿Cuántas columnas son numéricas y cuántas cualitativas?
# >**Hay 8 numericas y 4 cualitativas**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
#  2. Determina el porcentaje de valores faltantes por columna.

# %%
df.isna().mean() * 100
# Out:
# person_age                    0.000000
# person_income                 0.000000
# person_home_ownership         0.000000
# person_emp_length             2.747000
# loan_intent                   0.000000
# loan_grade                    0.000000
# loan_amnt                     0.000000
# loan_int_rate                 9.563856
# loan_status                   0.000000
# loan_percent_income           0.000000
# cb_person_default_on_file     0.000000
# cb_person_cred_hist_length    0.000000
# dtype: float64

# %% [markdown]
# # Análisis de variables numéricas

# %% [markdown]
# 3. Obtén las siguientes estadísticas descriptivas para todas las variables numéricas:
# *   Tendencia central (media, mediana)
# *   Dispersión o variabilidad (min, max, desviación estándar, cuartiles)
# *   Forma (asimetría y curtosis)
# *   Clasifica las variables `person_age` y `loan_in_rate` según los valores observados de asimetría y curtosis
#
# **NOTA**. Recuerda que muchas de estas estadísticas, puedes obtenerlas utilizando la función `describe()` y que la mediana está representada en el 2do cuartil (50%)

# %%
def formaDatos(df_ : pd.DataFrame):
  desc = df_.describe()
  n = df_.select_dtypes('number')
  cn = n.columns.to_list()
  indData=['Media','1er Cuartil','Mediana','3er Cuartil','Min','Max','Desv. Estd.','Valor simetria','Forma','Valor curtosis','Tipo curtosis']
  listData = []
  colName = []
  for col in cn:
    media = desc[col]['mean']
    Q1 = mean = desc[col]['25%']
    Q2 = mean = desc[col]['50%']
    Q3 = mean = desc[col]['75%']
    min = mean = desc[col]['min']
    max = mean = desc[col]['max']
    devStandard = mean = desc[col]['std']
    s = df_[col].skew(skipna = True)
    k = df_[col].kurt(skipna = True)
    sim = 'Simetrica' if s==0 else 'Asimetrica (Sesgo negativo)' if s < 0 else 'Asimetrica (Sesgo positivo)' if s > 0 else ''
    kur = 'Mesocúrtica' if k < 0.1 and k > -0.1  else 'Leptocúrtica' if k >= 0.1 else 'Platicúrtica' if k <= -0.1 else ''
    datosSerie = pd.Series(data=[media,Q1,Q2,Q3,min,max,devStandard,s,sim,k,kur], index=indData, name=col)
    res = pd.DataFrame(datosSerie, index=indData,columns=[col])
    listData.append(res)

  result = pd.concat(listData,axis=1)
  display(result)
  del(result,n)

# %%
formaDatos(df)
#Respuesta:
print('\nLos datos en la columna person_age muestran que su distribución genera una forma asimetrica con sesgo positivo (concentracion de valores a la izquierda y cola de valores a la derecha)\n causada por los valores atípicos tales como edades superiores a los 100 años (lo cual genera curtosis positiva). \n \nPor su parte loan_in_rate, de igual manera su forma es asimetrica con sesgo positivo (muy cercano a cero), sin embargo difiere en curtosis la cual es negativa\n lo que indica que todos sus valores estan mas extendidos o alejados de la media.')
# Out:
#                                  person_age                person_income  \
# Media                               27.7346                  66074.84847
# 1er Cuartil                            23.0                      38500.0
# Mediana                                26.0                      55000.0
# 3er Cuartil                            30.0                      79200.0
# Min                                    20.0                       4000.0
# Max                                   144.0                    6000000.0
# Desv. Estd.                        6.348078                 61983.119168
# Valor simetria                     2.581393                    32.865349
# Forma           Asimetrica (Sesgo positivo)  Asimetrica (Sesgo positivo)
# Valor curtosis                    18.560825                  2693.272776
# Tipo curtosis                  Leptocúrtica                 Leptocúrtica
#
#                           person_emp_length                    loan_amnt  \
# ...

# %% [markdown]
# 4. Utiliza histogramas para determinar la distribución de los valores representados en cada variable.
# *   ¿Se corresponde con lo obtenido en el cálculo de asimetría? Como verás, los datos reales son más complejos que la teoría. Por esta razón, recuerda siempre acompañar el análisis de la asimetría con algún gráfico como un histograma.
#
# **NOTA**. Para esto también puedes ocupar los gráficos `kde` ([kernel density estimation](https://www.cienciadedatos.net/documentos/pystats02-kernel-density-estimation-kde-python.html)) que crean una curva continua y suave expandiendo la idea del histograma.

# %%
from scipy import stats
from sklearn.neighbors import KernelDensity
modelo_kde = KernelDensity(kernel='linear', bandwidth=1)

i=0
j=0

f, axs = plt.subplots(2, 4, figsize=(20, 10))

for g in df.describe(exclude=object).columns:
  modelo_kde.fit(X=df[g].dropna().to_numpy().reshape(-1, 1))
  min = df[g].min()
  max = df[g].max()
  dDesc = df[g].describe()
  densmax = df[g].value_counts().max()
  puntos = len(df[g].dropna().unique())
  X_grid = np.linspace(min, max, puntos)
  densidad = (stats.norm.pdf(x=X_grid, loc=dDesc['mean'], scale=dDesc['std']))
  log_densidad_pred = modelo_kde.score_samples(X_grid.reshape((-1,1)))
  densidad_pred = np.exp(log_densidad_pred)
  axs[i,j].set_title(g)
  axs[i,j].hist(df[g].values, density=True, color="#3182bd", alpha=0.5)
  axs[i,j].plot(df[g], np.full_like(df[g], -0.001), '|k', markeredgewidth=1)
  axs[i,j].plot(X_grid,densidad, color = 'blue', label='verdadera distribución')
  axs[i,j].plot(X_grid, densidad_pred, color = 'red', label='predicción')
  i+=1
  if i > 1:
    j+=1
    i=0

#Respuesta
print('>Corresponde en parte, destaca que loan_int_rate es bimodal')
# Out:
# >Corresponde en parte, destaca que loan_int_rate es bimodal

# %%
#Histograma plano de prueba
# plt.rcParams["figure.figsize"] = (10, 10)
# df.hist()

# %% [markdown]
# 5. Emplea boxplots para mostrar la distribución de los datos a través de sus cuartiles.

# %%
df.plot(kind ='box',subplots=True, layout=(2,4),figsize=(10, 20))
# Out:
# person_age                       Axes(0.125,0.53;0.168478x0.35)
# person_income                 Axes(0.327174,0.53;0.168478x0.35)
# person_emp_length             Axes(0.529348,0.53;0.168478x0.35)
# loan_amnt                     Axes(0.731522,0.53;0.168478x0.35)
# loan_int_rate                    Axes(0.125,0.11;0.168478x0.35)
# loan_status                   Axes(0.327174,0.11;0.168478x0.35)
# loan_percent_income           Axes(0.529348,0.11;0.168478x0.35)
# cb_person_cred_hist_length    Axes(0.731522,0.11;0.168478x0.35)
# dtype: object

# %% [markdown]
# *   Como podrás observar hay valores atípicos en todas las variables. Ejecuta el siguiente código para identificar los valores atípicos en la variable `person_age`

# %%
percentile_25 = df["person_age"].quantile(0.25)
percentile_75 = df["person_age"].quantile(0.75)
iqr = percentile_75 - percentile_25
upper_limit = percentile_75 + 1.5 * iqr
lower_limit = percentile_25 - 1.5 * iqr
IQR_outliers = df[(df["person_age"] < lower_limit) | (df["person_age"] > upper_limit)]
IQR_outliers['person_age']
# Out:
# 81       144
# 183      144
# 575      123
# 747      123
# 29121     50
#         ...
# 32576     57
# 32577     54
# 32578     65
# 32579     56
# 32580     66
# Name: person_age, Length: 1494, dtype: int64

# %% [markdown]
# # Análisis de variables de texto

# %% [markdown]
#  6. Obtén las siguientes estadísticas descriptivas para todas las variables de texto:
# *   Tendencia central (moda)
# *   Cardinalidad (cantidad de valores únicos)
# *   Recuentos únicos (número de ocurrencias para cada valor único)
#
# **NOTA**. Un resumen de estas estadísticas, puedes obtenerlas indicando en la función `describe()` que se incluirán sólo las variables de tipo object: `describe(include = 'object')`. Para los recuentos utiliza la función `df['columna'].value_counts()`

# %%
descDf = df.describe(include='object')
lDatos = []
indiceD = ['Moda','Cardinalidad']

for c in descDf.columns:
    tr = pd.DataFrame(pd.Series(data=[descDf[c]['top'],descDf[c]['unique']],index=indiceD,name=c),index=indiceD,columns=[c])
    lDatos.append(tr)

result = pd.concat(lDatos,axis=1)
display(result)

for c in descDf.columns:
   display(df[c].value_counts())
# Out:
#              person_home_ownership loan_intent loan_grade  \
# Moda                          RENT   EDUCATION          A
# Cardinalidad                     4           6          7
#
#              cb_person_default_on_file
# Moda                                 N
# Cardinalidad                         2
# person_home_ownership
# RENT        16446
# MORTGAGE    13444
# OWN          2584
# OTHER         107
# Name: count, dtype: int64
# loan_intent
# EDUCATION            6453
# MEDICAL              6071
# VENTURE              5719
# PERSONAL             5521
# DEBTCONSOLIDATION    5212
# HOMEIMPROVEMENT      3605
# Name: count, dtype: int64
# loan_grade
# A    10777
# B    10451
# C     6458
# D     3626
# E      964
# F      241
# G       64
# Name: count, dtype: int64
# cb_person_default_on_file
# N    26836
# Y     5745
# Name: count, dtype: int64

# %% [markdown]
# 7. Utiliza gráficos de barras por variable para representar la frecuencia de cada categoría.
#
# **NOTA**. seaborn posee un gráfico de recuento, para variables de tipo object, que calcula la frecuencia de cada categoría sin necesidad de utilizar la función `value_counts()`. Para generarlo debes indicar la columna: `sns.countplot(x='columna', data=df) `

# %%
f, axs = plt.subplots(1, len(descDf.columns), figsize=(20, 4))
for g, ax in zip(descDf.columns, axs):
  sns.countplot(x=g,data=df,ax=ax).tick_params('x',labelrotation=90)

# %% [markdown]
# # **Parte 2**. Análisis de correlación (bivariante y multivariante)

# %% [markdown]
# La variable `loan_status` será la variable de salida (o a predecir en un modelo de ML). Analiza su relación con el resto de las variables a través de los siguientes gráficos:
#
# 8. Un box plot para visualizar la distribución de `loan_percent_income` según el `loan_status`. Interpreta el resultado.
#
# >**La relacion prestamo/ingreso es menor, cuando el estado del prestamo es falso o no activo. Aún así, se observa que hay mayor numero de valores atípicos en dicho caso.**

# %%
#Respuesta arriba

plt.rcParams["figure.figsize"] = (5, 5)
sns.boxplot(x='loan_status', y='loan_percent_income',data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_percent_income'>

# %% [markdown]
#  9. En los gráficos de barras que obtuviste en el ejercicio 7, separa el conteo según el `load_status`, utilizando el parámetro `hue`.

# %%
f, axs = plt.subplots(1, len(descDf.columns), figsize=(20, 4))
for g, ax in zip(descDf.columns, axs):
  sns.countplot(x=g,data=df.set_index('loan_status'),ax=ax,hue='loan_status').tick_params('x',labelrotation=90)

# %% [markdown]
# 10. Un mapa de calor con los valores de correlación de todas las variables del dataframe.
# *   ¿Qué variable tiene mayor correlación con `loan_status`?
#
# >**La variable loan_percent_income**

# %%
#Respuesta arriba

for col in df.select_dtypes(include=object).columns:
  df[col] = df[col].astype('category').cat.codes

f, axs = plt.subplots(1, 2, figsize=(20, 5))
axs[0].set_title('Heatmap de todas las variables')
sns.heatmap(df.corr(),ax=axs[0],annot=True)

axs[1].set_title('Heatmap de loan_status')
sns.heatmap(df.corr()[['loan_status']].sort_values(by=['loan_status'],ascending=False),ax=axs[1],annot=True)
# Out:
# <Axes: title={'center': 'Heatmap de loan_status'}>
