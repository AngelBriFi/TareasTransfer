# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana 02**
# ###**Introducción al procesamiento de texto.**

# %% [markdown]
# En esta actividad deberás utilizar los datos del siguiente archivo que se encuentra en Canvas:
#
# MNA_NLP_semana_02_Actividad_datos.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open('/content/sample_data/MNA_NLP_semana_02_Actividad_datos.txt',        # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comentario por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[0:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\n',
#  'Crust is not good.\n',
#  'Not tasty and the texture was just nasty.\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\n',
#  'The selection on the menu was great and so were the prices.\n',
#  'Now I am getting angry and I want my damn pho.\n',
#  "Honeslty it didn't taste THAT fresh.)\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\n',
#  'The fries were great too.\n',
#  'A great touch.\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n' que se encuentran al final de cada comentario.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %%
DocsSinSaltos = [re.sub(r'\n+$', '', comentario) for comentario in docs]

# %%
DocsSinSaltos[0:10]
# Out:
# ['Wow... Loved this place.',
#  'Crust is not good.',
#  'Not tasty and the texture was just nasty.',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#  'The selection on the menu was great and so were the prices.',
#  'Now I am getting angry and I want my damn pho.',
#  "Honeslty it didn't taste THAT fresh.)",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.',
#  'The fries were great too.',
#  'A great touch.']

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %%
multiplesSignos = 0
patron = re.compile(r'(\b\w+)(!{2,})')#patron = r"\b([^\W\d_]+)!{2,}"
for frase in DocsSinSaltos:
  for palabra, signos in re.findall(patron, frase):
    multiplesSignos += 1
    print(palabra,'---',len(signos))
# Out:
# Firehouse --- 5
# APPETIZERS --- 3
# amazing --- 3
# buffet --- 3
# good --- 2
# it --- 4
# DELICIOUS --- 2
# amazing --- 2
# shawarrrrrrma --- 6
# yucky --- 3
# steak --- 5
# delicious --- 3
# far --- 2
# biscuits --- 3
# dry --- 2
# disappointing --- 3
# awesome --- 2
# Up --- 2
# FLY --- 8
# here --- 3
# great --- 14
# packed --- 2
# otherwise --- 2
# amazing --- 19
# style --- 2
# disappointed --- 2

# %%
print(f"Se encontraron: {multiplesSignos} casos con multiples signos de amiración")
# Out:
# Se encontraron: 26 casos con multiples signos de amiración

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra.
#
# Indica cuántas palabras encontraste.

# %%
todoMayus = 0
patron = r"\b[A-Z]+\b"
for frase in DocsSinSaltos:
  for palabra in re.findall(patron, frase):
    todoMayus += 1
    print(palabra)
# Out:
# I
# I
# THAT
# A
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# APPETIZERS
# A
# I
# I
# I
# I
# I
# I
# I
# WILL
# NEVER
# EVER
# STEP
# FORWARD
# IN
# IT
# AGAIN
# I
# LOVED
# I
# AND
# REAL
# I
# I
# I
# I
# BITCHES
# I
# I
# I
# I
# NYC
# I
# I
# I
# I
# I
# I
# I
# STALE
# I
# I
# DELICIOUS
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# WORST
# EXPERIENCE
# EVER
# I
# ALL
# I
# BARGAIN
# I
# TV
# NONE
# I
# M
# FREEZING
# AYCE
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# FLAVOR
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# NEVER
# I
# I
# I
# I
# BBQ
# I
# A
# I
# UNREAL
# I
# I
# I
# I
# I
# I
# OMG
# I
# BETTER
# I
# I
# BLAND
# I
# I
# I
# I
# I
# I
# I
# RUDE
# INCONSIDERATE
# MANAGEMENT
# I
# I
# WILL
# NEVER
# EVER
# GO
# BACK
# AND
# HAVE
# TOLD
# MANY
# PEOPLE
# WHAT
# HAD
# HAPPENED
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# TOTAL
# WASTE
# OF
# TIME
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# ...

# %%
print(f"Se encontraron: {todoMayus} casos de palabras totalmente en mayusculas")
# Out:
# Se encontraron: 455 casos de palabras totalmente en mayusculas

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %%
fraseConPalMayus = 0
lfra=[]
patron = r"\b[A-Z]+\b"
for frase in DocsSinSaltos:
  if len(re.findall(patron, frase)) > 0:
    fraseConPalMayus += 1
    print(frase)
# Out:
# Now I am getting angry and I want my damn pho.
# Honeslty it didn't taste THAT fresh.)
# A great touch.
# The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.
# "I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!"
# I was disgusted because I was pretty sure that was human hair.
# I was shocked because no signs indicate cash only.
# I could care less... The interior is just beautiful.
# I found this place by accident and I could not be happier.
# "Overall, I like this place a lot."
# "Poor service, the waiter made me feel like I was stupid every time he came to the table."
# The only thing I did like was the prime rib and dessert section.
# At least think to refill my water before I struggle to wave you over for 10 minutes.
# This place receives stars for their APPETIZERS!!!
# A great way to finish a great.
# ...

# %%
print(f"Se encontraron: {fraseConPalMayus} casos de frases con palabras totalmente en mayusculas")
# Out:
# Se encontraron: 350 casos de frases con palabras totalmente en mayusculas

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %%
palabraAcent = 0
aPal=[]
patron = r'\b\w*[áéíóúÁÉÍÓÚ]\w*\b'
for frase in DocsSinSaltos:
  for palabra in re.findall(patron, frase):
    aPal.append(palabra)
    palabraAcent += 1
    print(palabra)
# Out:
# fiancé
# Café
# puréed

# %%
print(f"Se encontraron: {palabraAcent} casos de palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú")
# Out:
# Se encontraron: 3 casos de palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %%
cantidadesNum = 0
cMonL=[]
patron = r"\$\d+(?:\.\d+)?"
for frase in DocsSinSaltos:
  for palabra in re.findall(patron, frase):
    cMonL.append(palabra)
    cantidadesNum += 1
    print(palabra)
# Out:
# $20
# $4.00
# $17
# $3
# $35
# $7.85
# $12
# $11.99

# %%
print(f"Se encontraron: {cantidadesNum} casos de cantidades numéricas monetarias")
# Out:
# Se encontraron: 8 casos de cantidades numéricas monetarias

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love", sin importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra.
#
# Indica cuántos resultados obtuviste.

# %%
lCount = 0
patron = r"\b(lov\w*)\b"
for fr in nDocs:
  for p in re.findall(patron, fr, re.IGNORECASE):
    lCount += 1
print(f"Se encontraron: {cMon} veces love y/o conjugaciones")
# Out:
# Se encontraron: 8 veces love y/o conjugaciones

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras, variantes de "so" y "good", que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Indica cuántas encontraste.

# %%
oCount = 0
patron = r"\b(so{o,}|go{3,}d)\b"
for fr in nDocs:
  for p in re.findall(patron, fr, re.IGNORECASE):
    oCount += 1
print(f"Se encontraron: {oCount} variantes de \"so\" y \"good\", que tengan dos o más \"o\" en \"so\" y 3 o más \"o\" en good")
# Out:
# Se encontraron: 0 variantes de "so" y "good", que tengan dos o más "o" en "so" y 3 o más "o" en good

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 10 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %%
oCount = 0
patron = r"\b[a-zA-Z]{11,}\b"
for fr in nDocs:
  for p in re.findall(patron, fr):
    oCount += 1
print(f"Se encontraron: {oCount} palabras que con longitud mayor a 10 caracteres alfabéticos")
# Out:
# Se encontraron: 141 palabras que con longitud mayor a 10 caracteres alfabéticos

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string.
#
# Indica la cantidad de resultados obtenidos.

# %%
oCount = 0
patron = r"(?:^|\W+)([A-Z][a-z]*[a-z])\b"
for fr in nDocs:
  for p in re.findall(patron, fr):
    oCount += 1
print(f"Se encontraron: {oCount} palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string")
# Out:
# Se encontraron: 1063 palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían.
#
# Indica la cantidad de resultados obtenidos.

# %%
oCount = 0
patron = r"\b[a-zA-Z]+(?:-[a-zA-Z]+)+\b"
for fr in nDocs:
  for p in re.findall(patron, fr):
    oCount += 1
print(f"Se encontraron: {oCount} palabras que están separadas por un guion, \"-\", sin que tengan espacios en blanco entre ellas")
# Out:
# Se encontraron: 19 palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan en "ing" o "ed".
#
# Indica la cantidad de palabras que encontraste de cada una.

# %%
oCount = 0
patron = r"\b[a-zA-Z]+(?:ing|ed)"
for fr in nDocs:
  for p in re.findall(patron, fr):
    oCount += 1
print(f"Se encontraron: {oCount} palabras que terminan en \"ing\" o \"ed\"")
# Out:
# Se encontraron: 662 palabras que terminan en "ing" o "ed"

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
def limpiar_texto(texto):
    # 1. Convertir a minúsculas
    texto = texto.lower()

    # 2. Mantener solo caracteres alfabéticos y espacios
    texto = re.sub(r'[^a-z\s]', ' ', texto)

    # 3. Reemplazar múltiples espacios por uno solo
    texto = re.sub(r'\s+', ' ', texto)

    # 4. Eliminar espacios al inicio y final
    texto = texto.strip()

    return texto

# %%
# Suponiendo que tu corpus está en una lista llamada "corpus"
corpus_limpio = [limpiar_texto(comentario) for comentario in docs]

# Imprimir los primeros 10 comentarios limpios
for i, comentario in enumerate(corpus_limpio[:10], start=1):
    print(f"{i}. {comentario}")
# Out:
# 1. wow loved this place
# 2. crust is not good
# 3. not tasty and the texture was just nasty
# 4. stopped by during the late may bank holiday off rick steve recommendation and loved it
# 5. the selection on the menu was great and so were the prices
# 6. now i am getting angry and i want my damn pho
# 7. honeslty it didn t taste that fresh
# 8. the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer
# 9. the fries were great too
# 10. a great touch

# %% [markdown]
# *   **Pregunta 14.**
#
# Con el resultado de la limpieza obtenido en la pregunta anterior, realiza ahora un proceso de tokenización por palabras del corpus.
#
# Es decir, al final de este proceso de tokenización, debes tener como resultado una lista de listas, donde cada comentario estará tokenizado por palabras.
#
# Al terminar calcula el total de tokens obtenido en todo el corpus.

# %%
def tokenizar_comentario(texto):
    return texto.split()

# %%
# Tokenizar todo el corpus
corpus_tokenizado = [tokenizar_comentario(comentario) for comentario in corpus_limpio]

# Calcular total de tokens
total_tokens = sum(len(comentario) for comentario in corpus_tokenizado)

# Mostrar primeros 10 comentarios tokenizados
for i, comentario in enumerate(corpus_tokenizado[:10], start=1):
    print(f"{i}. {comentario}")

print("\nTotal de tokens en el corpus:", total_tokens)
# Out:
# 1. ['wow', 'loved', 'this', 'place']
# 2. ['crust', 'is', 'not', 'good']
# 3. ['not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty']
# 4. ['stopped', 'by', 'during', 'the', 'late', 'may', 'bank', 'holiday', 'off', 'rick', 'steve', 'recommendation', 'and', 'loved', 'it']
# 5. ['the', 'selection', 'on', 'the', 'menu', 'was', 'great', 'and', 'so', 'were', 'the', 'prices']
# 6. ['now', 'i', 'am', 'getting', 'angry', 'and', 'i', 'want', 'my', 'damn', 'pho']
# 7. ['honeslty', 'it', 'didn', 't', 'taste', 'that', 'fresh']
# 8. ['the', 'potatoes', 'were', 'like', 'rubber', 'and', 'you', 'could', 'tell', 'they', 'had', 'been', 'made', 'up', 'ahead', 'of', 'time', 'being', 'kept', 'under', 'a', 'warmer']
# 9. ['the', 'fries', 'were', 'great', 'too']
# 10. ['a', 'great', 'touch']
#
# Total de tokens en el corpus: 11039

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras "stopwords", las cuales deberás eliminar de todo el corpus.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera, que tienen frecuencias de aparición muy altas en cualquier documento, pero que no brindan mucho significado en cuanto al significado de un enunciado.
#
# Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior.
#
# Obtener cuántos tokens/palabras quedan finalmente en todo el corpus.
#
# Obtener cuántos de estos tokens/palabras son diferentes, es decir, cuántos tokens únicos tendrá lo que llamaremos más adelante nuestro vocabulario.

# %%
# Considera la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']

# %%
stopwords = set(mis_stopwords)

def eliminar_stopwords(tokens):
    return [tok for tok in tokens if tok not in stopwords]

# %%
# Aplicar eliminación de stopwords a todo el corpus
corpus_sin_stopwords = [eliminar_stopwords(comentario) for comentario in corpus_tokenizado]

# Calcular total de tokens finales
total_tokens_final = sum(len(comentario) for comentario in corpus_sin_stopwords)

# Calcular vocabulario único
vocabulario = set(tok for comentario in corpus_sin_stopwords for tok in comentario)
total_vocabulario = len(vocabulario)

# Mostrar primeros 10 comentarios sin stopwords
for i, comentario in enumerate(corpus_sin_stopwords[:10], start=1):
    print(f"{i}. {comentario}")

print("\nTotal de tokens después de eliminar stopwords:", total_tokens_final)
print("Total de tokens únicos (vocabulario):", total_vocabulario)
# Out:
# 1. ['wow', 'loved', 'place']
# 2. ['crust', 'not', 'good']
# 3. ['not', 'tasty', 'texture', 'nasty']
# 4. ['stopped', 'late', 'may', 'bank', 'holiday', 'off', 'rick', 'steve', 'recommendation', 'loved']
# 5. ['selection', 'menu', 'great', 'prices']
# 6. ['getting', 'angry', 'want', 'damn', 'pho']
# 7. ['honeslty', 'didn', 'taste', 'fresh']
# 8. ['potatoes', 'like', 'rubber', 'could', 'tell', 'made', 'ahead', 'time', 'kept', 'warmer']
# 9. ['fries', 'great']
# 10. ['great', 'touch']
#
# Total de tokens después de eliminar stopwords: 5783
# Total de tokens únicos (vocabulario): 1910

# %% [markdown]
# *   **Comentarios**
#
# Incluye finalmente tus comentarios de la actividad.

# %% [markdown]
# << incluye aquí tus comentarios >>

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
