# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 5**
# Preprocesamiento de datos
#
# ---

# %% [markdown]
# *   NOMBRE: Angel Irwin Briseño Fierro
# *   MATRÍCULA: A01796844

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
#DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento"
DIR = '/content/drive/MyDrive/CienciayAnaliticadeDatos_Datos'
os.chdir(DIR)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
response_df = pd.read_csv('responses.csv')
response_df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 1. Determina cuántas variables numéricas y cuántas de texto posee el conjunto de datos con el método `info()` y utiliza el método `describe()` del dataframe, para obtener el resumen de las estadísticas descriptivas. Separa el análisis según el tipo de datos (number, object).

# %%
response_df.info() #139 numericos y 11 objectos
display(response_df.describe(exclude=object))
display(response_df.describe(exclude=np.number))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# ...

# %% [markdown]
# 2. Clasifique la variable `Weight` según su escala de medición. En función de ello elija el gráfico a generar (histograma / barras) y fundamente su elección.
# >**En función al tipo de dato, que es continuo, se elige el histograma.**

# %%
response_df['Weight'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 3. Clasifique la distribución del peso según su asimetría, justificando tu respuesta. Incluye el cálculo numérico que lo demuestra.
# >**Tenemos un sesgo positivo a la derecha (datos mayormente agrupados a la izquierda lo cual genera una cola a su derecha).**

# %%
response_df['Weight'].skew()
# Out:
# 1.2237251927527477

# %% [markdown]
# 4. ¿Cuántos valores faltantes tiene la variable `Weight`? ¿Qué porcentaje representa?

# %%
vf = response_df['Weight'].isna().sum()
pf = response_df['Weight'].isna().mean() * 100
display(f'Hay {vf} valores faltantes que representan un {pf:.2f}%')
# Out:
# 'Hay 20 valores faltantes que representan un 1.98%'

# %% [markdown]
# 5. ¿Tendrán los valores faltantes de `Weight` relación con alguna otra variable? Analízalo considerando las siguientes columnas:
# *   Numéricas: `Age, Number of siblings`
# *   Categóricas: `Gender, Education`
#
# Para ello deberás dividir cada columna en dos grupos: con/sin faltantes en `Weight` y utilizar métodos gráficos y la prueba t para ver si hay diferencias significativas. NO olvides incluir las conclusiones del análisis con los resultados obtenidos.
#
# **NOTA**. Puedes reutilizar las funciones `Diagnose_MV_Numerical` y `Diagnose_MV_Categorical` definidas en Hands-On-Prep_Missing_Values.zip. Revisa nuevamente cómo utilizarlas.

# %%
from scipy.stats import ttest_ind
def Diagnose_MV_Numerical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    labels=[]
    box_sr = pd.Series('',index = BM_MV.unique())
    for poss in BM_MV.unique():
        BM = BM_MV == poss
        box_sr[poss] = df[BM][str_att_name].dropna()
        labels.append(MV_labels[poss])

    plt.figure(figsize=(5,4))

    plt.boxplot(box_sr,vert=False)
    plt.yticks([1,2],labels)
    plt.xlabel(str_att_name)
    plt.show()

    plt.figure(figsize=(10,4))

    att_range = (df[str_att_name].min(),df[str_att_name].max())

    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].hist()
        plt.xlim = att_range
        plt.xlabel(str_att_name)
        plt.title(MV_labels[poss])

    plt.show()

    group_1_data = df[BM_MV][str_att_name].dropna()
    group_2_data = df[~BM_MV][str_att_name].dropna()

    p_value = ttest_ind(group_1_data,group_2_data).pvalue

    print('p-value of t-test: {}'.format(p_value))

# %%
from scipy.stats import chi2_contingency
def Diagnose_MV_Categorical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    plt.figure(figsize=(10,4))
    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].value_counts().plot.bar()
        plt.title(MV_labels[poss])
    plt.show()

    contigency_table = pd.crosstab(BM_MV,df[str_att_name])
    p_value = chi2_contingency(contigency_table)[1]

    print('p-value of Chi_squared test: {}'.format(p_value))

# %%
print('''Valores perdidos para "Number of siblings"''')
Diagnose_MV_Numerical(response_df,'Weight',response_df['Number of siblings'].isna())
print()
print('''Valores perdidos para "Age"''')
Diagnose_MV_Numerical(response_df,'Weight',response_df['Age'].isna())
print()
print('''Valores perdidos para "Gender"''')
Diagnose_MV_Numerical(response_df,'Weight',response_df['Gender'].isna())
print()
print('''Valores perdidos para "Education"''')
Diagnose_MV_Numerical(response_df,'Weight',response_df['Education'].isna())
# Out:
# Valores perdidos para "Number of siblings"
# p-value of t-test: nan
#
# Valores perdidos para "Age"
# p-value of t-test: 0.3756777426276473
#
# Valores perdidos para "Gender"
# p-value of t-test: 0.7211552190644392
#
# Valores perdidos para "Education"
# p-value of t-test: 0.23582185641506626

# %% [markdown]
# Respuesta a pregunta 5:
# >**La información muestra que la relacion con `Number of siblings` es totalmente dependiente, sin embargo, dada la coincidencia de valores nulos en ambos casos puede que se requieran mas datos para dicho análisis. Por su parte, el resto de las variables son independientes (p-value >= α donde α = 0.05), dicho de otra manera, no se rechaza la hipotesis nula.**

# %% [markdown]
# 6. Utiliza una medida de tendencia central para imputar los valores faltantes de `Weight`. ¿Cuál es recomendable y por qué?
# >**Dado que la distribucion esta sesgada, la *mediana* seria lo recomendable. De esta manera la imputación no se veria afectada por los valores atípicos.**

# %%
print(f'Valores Nan antes de imputar valores: {response_df["Weight"].isna().sum()}')
medianaW=response_df['Weight'].median()
response_df['Weight'] = response_df['Weight'].fillna(value=medianaW)
print(f'Valores Nan después de imputar valores: {response_df["Weight"].isna().sum()}')
# Out:
# Valores Nan antes de imputar valores: 20
# Valores Nan después de imputar valores: 0

# %% [markdown]
# 7. ¿Hay valores atípicos de la variable `Weight`? Confírmalo con un gráfico de boxplot. ¿Cuántos son? Almacénalos en un dataframe independiente y elimínalos del conjunto original.

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
ax1.set_title('Datos con outliers')
response_df.Weight.to_frame().boxplot(ax=ax1)

Q1 = response_df.Weight.describe()['25%']
Q3 = response_df.Weight.describe()['75%']
IQR = Q3 - Q1
LL = Q1 - 1.5*IQR
HL = Q3 + 1.5*IQR
Outliers_df = response_df[response_df['Weight'] > HL]
display(f'Si hay valores atipicos, en total, utilizando el metodo IQR se obtienen: {Outliers_df.Weight.count()}')
response_df.drop(Outliers_df.index,inplace=True)
ax2.set_title('Datos sin outliers')
response_df.Weight.to_frame().boxplot(ax=ax2)
print()
plt.tight_layout()
# Out:
# 'Si hay valores atipicos, en total, utilizando el metodo IQR se obtienen: 10'

# %% [markdown]
# 8. Repite el mismo proceso de valores atípicos con la variable `Height`.

# %%
response_df.Heights.to_frame().boxplot()

Q1 = response_df.Heights.describe()['25%']
Q3 = response_df.Heights.describe()['75%']
IQR = Q3 - Q1
LL = Q1 - 1.5*IQR
HL = Q3 + 1.5*IQR
Outliers_df = response_df[response_df['Heights'] > HL]
display(f'No hay valores atipicos, utilizando el metodo IQR se obtienen: {Outliers_df.Heights.T.count()}')
response_df.drop(Outliers_df.index,inplace=True)
# Out:
# 'No hay valores atipicos, utilizando el metodo IQR se obtienen: 0'

# %% [markdown]
# 9. ¿Hay encuestados que sean atípicos según su índice de masa corporal (`BMI`)? El `BMI` puede ser calculado usando la siguiente fórmula:
#
# `BMI = Weight / Height ^ 2`
#
# **NOTA**. El peso tiene que estar en kilogramos y la altura en metros, pero en el conjunto la altura se ha registrado en centímetros, por lo que deberás convertirla a metros.

# %%
BMI = pd.Series(response_df['Weight']/((response_df['Height']/100)**2),name='BMI')
response_df = pd.concat((response_df,BMI),axis=1)
response_df['BMI']
# Out:
# 0       18.066167
# 1       21.829952
# 2       21.629649
# 3       19.943213
# 4       20.415225
#           ...
# 1005    21.192742
# 1006    23.888441
# 1007    25.059307
# 1008    19.379197
# 1009    21.037253
# Name: BMI, Length: 1000, dtype: float64

# %% [markdown]
# 10. Utiliza boxplots para visualizar la distribución del `BMI` según cada una de las variables categóricas de texto. Comenta un hallazgo que llame tu atención.
# >**Lo que llamó mi atención fue que el BMI tiende a ser mayor en la distribución `Education` en el caso específico de `Doctorate degree`**

# %%
nombreCol = response_df.describe(exclude=np.number).columns
fig, axes = plt.subplots(2, round(len(nombreCol)/2 + 1), figsize=(15,15))
axes = axes.ravel()
for c , ax in zip(nombreCol,axes):
  sns.boxplot(data=response_df,x=c,y='BMI', ax=ax)
  ax.set(title=f'BMI según {c}',xlabel=None)
  ax.tick_params(labelrotation=90)

for ax in axes.flat[len(nombreCol):]:
    ax.remove()

plt.tight_layout()
