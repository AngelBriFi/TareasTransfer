# %% [markdown]
# # **Procesamiento de Lenguaje Natural**
#
# ## Maestría en Inteligencia Artificial Aplicada
# #### Tecnológico de Monterrey
# #### Prof Luis Eduardo Falcón Morales
#
# ### **Adtividad en Equipos Semanas 7 y 8 : LDA y LMM audio-a-texto**

# %% [markdown]
# * **Nombres y matrículas:**
#
#   *   Elemento de lista
#   *   Elemento de lista
#   *   Elemento de lista
#
# * **Número de Equipo:**

# %% [markdown]
# * ##### **En cada ejercicio pueden importar los paquetes o librerías que requieran.**
#
# * ##### **En cada ejercicio pueden incluir las celdas y líneas de código que deseen.**

# %% [markdown]
# # **Ejercicio 1:**

# %% [markdown]
# * #### **Liga de los audios de las fábulas de Esopo:** https://www.gutenberg.org/ebooks/21144
#
# * #### **Descargar los 10 archivos de audio solicitados: 1, 4, 5, 6, 14, 22, 24, 25, 26, 27.**

# %%
import requests

url = 'https://www.gutenberg.org/files/21144/mp3/21144-' # ##.mp3
filesL = [1, 4, 5, 6, 14, 22, 24, 25, 26, 27]

for f in filesL:
  txSt = f'{f}'
  if f < 10:
    txSt = '0'+txSt
  response = requests.get(url+f'{txSt}.mp3')

  # Check if the request was successful (status code 200)
  if response.status_code == 200:
      # Open a local file in binary write mode ('wb') and save the content
      with open(f'/content/sample_data/21144-{txSt}.mp3', "wb") as file:
          file.write(response.content)
      print("Download complete!")
  else:
      print(f"Failed to download file. Status code: {response.status_code}")
# Out:
# Download complete!
# Download complete!
# Download complete!
# Download complete!
# Download complete!
# Download complete!
# Download complete!
# Download complete!
# Download complete!
# Download complete!

# %%
from pydub import AudioSegment

for f in filesL:
  txSt = f'{f}'
  if f < 10:
    txSt = '0'+txSt
  src = f'/content/sample_data/21144-{txSt}.mp3'
  sound = AudioSegment.from_mp3(src)

  # Export as WAV format
  sound.export(f'/content/sample_data/21144-{txSt}.wav', format="wav")

  print("Conversion complete!")
# Out:
# Conversion complete!
# Conversion complete!
# Conversion complete!
# Conversion complete!
# Conversion complete!
# Conversion complete!
# Conversion complete!
# Conversion complete!
# Conversion complete!
# Conversion complete!

# %% [markdown]
# # **Ejercicio 2a:**

# %% [markdown]
# * #### **Comenten el por qué del modelo seleccionado para extracción del texto de los audios.**
#
# * #### **Extraer el contenido de los audios en texto.**
#
# * #### **Sugerencia:** pueden extraerlo en un formato de diccionario, clave:valor $→$ {audio01:fabula01, ...}

# %%
#!pip install "transformers>=5.3.0"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from transformers import pipeline
model = pipeline("automatic-speech-recognition", model="openai/whisper-base",
chunk_length_s=30,      # <-- key setting
    stride_length_s=5
)
# Out:
# Loading weights:   0%|          | 0/245 [00:00<?, ?it/s]
# [transformers] Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).

# %%
fText = []
filesL = [1, 4, 5, 6, 14, 22, 24, 25, 26, 27]
for f in filesL:
  txSt = f'{f}'
  if f < 10:
    txSt = '0'+txSt
  src = f'/content/sample_data/21144-{txSt}.wav'

  result = model(src)
  fText.append(result["text"])
  print(txSt,'Complete')
# Out:
# 01 Complete
# 04 Complete
# 05 Complete
# 06 Complete
# 14 Complete
# 22 Complete
# 24 Complete
# 25 Complete
# 26 Complete
# 27 Complete

# %%
import pickle

# with open('/content/drive/MyDrive/data/fText.pkl', 'wb') as f:
#     pickle.dump(fText, f)

with open('/content/drive/MyDrive/data/fText.pkl', 'rb') as f:
    fText = pickle.load(f)

# %%
fText
# Out:
# [' Las fábulas de sopo, grabado para librebox.org por Paulino www.paulino.info Fábula número 61, el lobo y el cordero en el templo. Tando se cuenta de que era perseguido por un lobo, un pequeño cordelito decidió refugiarse en un templo cercano. Lo llamó lobo y le dijo que si el sacrificador lo encontraba allí adentro, lo emolaría a su Dios. Mejor así replicó el cordero. Prefiero ser víctima para un Dios a tener que perecer en tus colmillos. Si sin remedio vamos a ser sacrificados, más nos vale que sea con el mayor honor. Fin de la Fábula Este es una grabación del dominio público.',
#  ' Las fábulas de sopo grabado para librebox.org por Roberto Antonio Muñoz, fábula número 64, el logo y la cruza. A un lobo que comía un hueso se le atragantó el hueso en la garganta y corría por todas partes en busca de auxilma. Encontro en su carrera una grulla y le pidió que le salvara de aquella situación y que enseguida le pagaría por ello. Hacepto la grulla e introdujo su cabeza en la boca del logo, sacando de la garcanta el hueso atravesado. Pidió entonces la cancelación de la paga convenida. Oye aniga, dijo el logo. No crees que es suficiente paga con haber sacado tu cabeza sana y salvada en mi boca? Nunca hagas favores a malvados, trascantes o corruptos, pues mucha paga tendrías si te dejan sano y salvo.',
#  ' Las fábulas de sopo, grabado para LibriVox.org por Karen Savage, fábula número 65, el lobo y el caballo. Pasaba un lobo por un sembrado de cebada, pero como no era comida de su gusto, la dejó y siguió su camino. Encontró al rato a un caballo y le llevó al campo comentándole la gran cantidad de cebada que había hallado, pero que en vez de comerse la él, mejor se la había dejado, porque le agradaban más o ir el ruido de sus dientes al masticarla. Pero el caballo le repuso, amigo, si los lobos conmieran cebada, no hubieras preferido complacer a tus oídos si no a tu estómago. A todo malvado, aunque parezca actuar como bueno, no debe de creírsele.',
#  ' Las fábulas de desopo, grabado para librebrox.org, por Alejandro González Calerón, fábula número 66, el lobo y el asno. Un lobo fue elegido rey entre sus congéneres y decretó una ley ordenando que lo que cada uno capturase en la casa, lo pusiera en común y lo repartiese por partes iguales entre todos. De esta manera, ya no tendría los lobos que devorarse unos a otros en épocas de hambre. Pero no hizole escucho un asno que estaba por ahí cerca y moviendo sus orejas le dijo, magnífica idea abrotado de tu corazón, pero ¿por qué se escondido todo tu botín en tu cueva, llevando a la comunidad y repártelo también como lo ha secretado? El lobo descubriarte confundido de Rogozulay. Si alguna vez llegas a tener poder de legislar, se el primero en cumplir tus propias leyes. Fín de la fábula. Esta grabación es de dominio público.',
#  ' Las fábulas de sopo, grabado para librevox.org por el ochito, fábula número 74, el lobo y el cabrito encerrado, protegido por la seguridad del corral de una casa, un cabrito vio pasar a un lobo y comenzó a insultarle burlando se ampliamente de él, El lobo serenamente le replicó. Infeliz, sé que no eres tú quien me está insultando sino el sitio en que te encuentras. Muy a menudo no es el valor sino la ocasión y el lugar quienes proveen el enfrentamiento arrogante ante los poderosos. Fin de la Fábula. Esta grabación es del dominio público.',
#  ' Las fábulas de esopo, grabado para librebox.org por el ochito. Fábula número 82, el perro y la alméja. Un perro de esos acostumbrados a comer huevos al ver una alméja, no lo pensó dos veces y creyendo que se trataba de un huevo, se la atragó inmediatamente. Descarradas luego sus entrañas se sintió muy mal y se dijo. Bien merecido lo tengo, por creer que todo lo que veo redondo son huevos. Nunca tomes un asunto sin antes reflexionar, para no entrar luego en extrañas dificultades. Fín de la faula. Esta grabación es del dominio público.',
#  ' Las fábulas de sopo, grabado para LibriVox.org por Karen Savage, fábula número 84, el perro y el reflejo en el río. Vadiaba un perro, un río, llevando en su hocico un sabroso pedazo de carne, vio su propio reflejo en el agua del río y creyó que aquel reflejo era, en realidad, otro perro, que llevaba un trozo de carne mayor que el suyo, y deseando adueñarse del pedazo ajeno, soltó el suyo para rebatar el trozo a su supuesto compadre. Pero el resultado fue que se quedó sin el propio y sin el ajeno. Este, porque no existía, sólo era un reflejo, y el otro, el verdadero, porque se lo llevó a la corriente. Nunca codíciese el bienajeno, pues puedes perder lo que ya has adquirido con tu esfuerzo.',
#  ' Las fábblas de esopo, grabada o paralipevox.org, fábola número 85, el pero y el carnicero. Penetro, un pero en una carnicería, inotando que el carnicero estaba muy ocupado con sus clientes, cogió introso de carne y se lió corriendo. Se volvió el carnicero, y viendole a huir, y sin No esperes a que suceda un accidente para pensar en cómo evitarlo.',
#  ' Las fábulas de sopo, grabado para librebox.org por el ochito. Fábula número 86, el perro con campanilla. Había un perro que acostumbraba a morder sin razón. Le puso su amo una campanilla para advertirle a la gente de su presencia cercana, y el can sonando la campanilla se fue a sí mismo, los fanfarrones, solo delatan sus mayores defectos. Finde la fábula, esta grabación es del dominio público.',
#  ' Las fábulas de Esopo, grabado para librivox.org por el ochito, fábula número 87. El perro que perseguía al león. Un perro de casas se encontró con un león y partió en su persecución, pero el león se volvió rugiendo y el perro todo a temorizado, retrocedió rápidamente por elabas. Fínde la faula, esta grabación es del dominio público.']

# %% [markdown]
# # **Ejercicio 2b:**

# %% [markdown]
# * #### **Eliminar el inicio y final comunes de los textos extraídos de cada fábula.**
#
# * #### **Sugerencia:** Pueden guardar esta información en un archivo tipo JSON, para que al estar probando diferentes opciones en los ejercicios siguientes, puedan recuperar rápidamente la información de cada video/fábula.

# %%
# Incluyan a continuación todas las celdas (de código o texto) que deseen...

import re

nText = []

for t in fText:
  txt = re.sub(r'^.*?f[áa]b[ou]la número \d+(?:,.*?\.)?\.?\s*', '', t,flags=re.IGNORECASE)
  txt = re.sub(r'F[íi]?n\s*de?\s*la\s*f[áa]bula[.,]?\s*.*$', '', txt, flags=re.IGNORECASE | re.DOTALL)

  nText.append(txt.strip())

nText
# Out:
# ['Tando se cuenta de que era perseguido por un lobo, un pequeño cordelito decidió refugiarse en un templo cercano. Lo llamó lobo y le dijo que si el sacrificador lo encontraba allí adentro, lo emolaría a su Dios. Mejor así replicó el cordero. Prefiero ser víctima para un Dios a tener que perecer en tus colmillos. Si sin remedio vamos a ser sacrificados, más nos vale que sea con el mayor honor.',
#  'A un lobo que comía un hueso se le atragantó el hueso en la garganta y corría por todas partes en busca de auxilma. Encontro en su carrera una grulla y le pidió que le salvara de aquella situación y que enseguida le pagaría por ello. Hacepto la grulla e introdujo su cabeza en la boca del logo, sacando de la garcanta el hueso atravesado. Pidió entonces la cancelación de la paga convenida. Oye aniga, dijo el logo. No crees que es suficiente paga con haber sacado tu cabeza sana y salvada en mi boca? Nunca hagas favores a malvados, trascantes o corruptos, pues mucha paga tendrías si te dejan sano y salvo.',
#  'Pasaba un lobo por un sembrado de cebada, pero como no era comida de su gusto, la dejó y siguió su camino. Encontró al rato a un caballo y le llevó al campo comentándole la gran cantidad de cebada que había hallado, pero que en vez de comerse la él, mejor se la había dejado, porque le agradaban más o ir el ruido de sus dientes al masticarla. Pero el caballo le repuso, amigo, si los lobos conmieran cebada, no hubieras preferido complacer a tus oídos si no a tu estómago. A todo malvado, aunque parezca actuar como bueno, no debe de creírsele.',
#  'Un lobo fue elegido rey entre sus congéneres y decretó una ley ordenando que lo que cada uno capturase en la casa, lo pusiera en común y lo repartiese por partes iguales entre todos. De esta manera, ya no tendría los lobos que devorarse unos a otros en épocas de hambre. Pero no hizole escucho un asno que estaba por ahí cerca y moviendo sus orejas le dijo, magnífica idea abrotado de tu corazón, pero ¿por qué se escondido todo tu botín en tu cueva, llevando a la comunidad y repártelo también como lo ha secretado? El lobo descubriarte confundido de Rogozulay. Si alguna vez llegas a tener poder de legislar, se el primero en cumplir tus propias leyes.',
#  'Infeliz, sé que no eres tú quien me está insultando sino el sitio en que te encuentras. Muy a menudo no es el valor sino la ocasión y el lugar quienes proveen el enfrentamiento arrogante ante los poderosos.',
#  'Un perro de esos acostumbrados a comer huevos al ver una alméja, no lo pensó dos veces y creyendo que se trataba de un huevo, se la atragó inmediatamente. Descarradas luego sus entrañas se sintió muy mal y se dijo. Bien merecido lo tengo, por creer que todo lo que veo redondo son huevos. Nunca tomes un asunto sin antes reflexionar, para no entrar luego en extrañas dificultades. Fín de la faula. Esta grabación es del dominio público.',
#  'Vadiaba un perro, un río, llevando en su hocico un sabroso pedazo de carne, vio su propio reflejo en el agua del río y creyó que aquel reflejo era, en realidad, otro perro, que llevaba un trozo de carne mayor que el suyo, y deseando adueñarse del pedazo ajeno, soltó el suyo para rebatar el trozo a su supuesto compadre. Pero el resultado fue que se quedó sin el propio y sin el ajeno. Este, porque no existía, sólo era un reflejo, y el otro, el verdadero, porque se lo llevó a la corriente. Nunca codíciese el bienajeno, pues puedes perder lo que ya has adquirido con tu esfuerzo.',
#  'Penetro, un pero en una carnicería, inotando que el carnicero estaba muy ocupado con sus clientes, cogió introso de carne y se lió corriendo. Se volvió el carnicero, y viendole a huir, y sin No esperes a que suceda un accidente para pensar en cómo evitarlo.',
#  'Había un perro que acostumbraba a morder sin razón. Le puso su amo una campanilla para advertirle a la gente de su presencia cercana, y el can sonando la campanilla se fue a sí mismo, los fanfarrones, solo delatan sus mayores defectos.',
#  'El perro que perseguía al león. Un perro de casas se encontró con un león y partió en su persecución, pero el león se volvió rugiendo y el perro todo a temorizado, retrocedió rápidamente por elabas. Fínde la faula, esta grabación es del dominio público.']

# %% [markdown]
# # **Ejercicio 3:**

# %% [markdown]
# * #### **Apliquen el proceso de limpieza que consideren adecuado.**
#
# * #### **Justifiquen los pasos de limpieza utilizados. Tomen en cuenta que el texto extraído de cada fábula es relativamente pequeño.**
#
# * #### **En caso de que decidan no aplicar esta etapa de limpieza, deberán justificarlo.**

# %%
# Incluyan a continuación todas las celdas (de código o texto) que deseen...

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords = stopwords.words('spanish')

docsTokens = []
docs = []
for f in nText:
  for stw in stopwords:
    f = re.sub(f'\\b{stw}\\b', '', f)
    f = re.sub(r"[.|,]", "", f)
    f = re.sub(r'\s+', ' ', f)
  docs.append(f)
  docsTokens.append([w.lower() for w in f.split(' ')])

for i in docsTokens:
  print(i[:5])
# Out:
# ['tando', 'cuenta', 'perseguido', 'lobo', 'pequeño']
# ['a', 'lobo', 'comía', 'hueso', 'atragantó']
# ['pasaba', 'lobo', 'sembrado', 'cebada', 'comida']
# ['un', 'lobo', 'elegido', 'rey', 'congéneres']
# ['infeliz', 'sé', 'insultando', 'sino', 'sitio']
# ['un', 'perro', 'acostumbrados', 'comer', 'huevos']
# ['vadiaba', 'perro', 'río', 'llevando', 'hocico']
# ['penetro', 'carnicería', 'inotando', 'carnicero', 'ocupado']
# ['había', 'perro', 'acostumbraba', 'morder', 'razón']
# ['el', 'perro', 'perseguía', 'león', 'un']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # **Ejercicio 4:**

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.2.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 28.1 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
# Incluyan a continuación todas las celdas (de código o texto) que deseen...

import gensim
from gensim.corpora import Dictionary
import gensim.corpora as corpora
from gensim.models import LdaModel

id2word = corpora.Dictionary(docsTokens)
corpus = [id2word.doc2bow(tok) for tok in docsTokens]
lda = LdaModel(corpus=corpus,
               id2word=id2word,
               num_topics=10,
               passes=20,
               random_state=42)
  # fab = f.lower()
  # fab = fab.split(' ')
  # vectorizer = CountVectorizer()
  # X = vectorizer.fit_transform(fab)


  # ldaList.append(LatentDirichletAllocation(n_components=1, random_state=42, learning_decay = 0.5))
  # ldaList[i].fit(X)

# %%
for topic_id in range(10):
    topic_words = lda.show_topic(topic_id, topn=20)
    keywords = [word for word, prob in topic_words]

    print(f"Fábula {topic_id+1} — Top {20} palabras clave:")
    print(keywords)
# Out:
# Fábula 1 — Top 20 palabras clave:
# ['sino', 'infeliz', 'poderosos', 'valor', 'proveen', 'muy', 'menudo', 'ocasión', 'sé', 'arrogante', 'encuentras', 'enfrentamiento', 'sitio', 'insultando', 'lugar', 'reflejo', 'pedazo', 'carne', 'trozo', 'propio']
# Fábula 2 — Top 20 palabras clave:
# ['hueso', 'paga', 'huevos', 'luego', 'perro', 'campanilla', 'dijo', 'nunca', 'grulla', 'cabeza', 'logo', 'pidió', 'fín', 'merecido', 'mal', 'tomes', 'redondo', 'reflexionar', 'pensó', 'inmediatamente']
# Fábula 3 — Top 20 palabras clave:
# ['león', 'perro', 'lobo', 'ser', 'dios', 'si', 'persecución', 'rugiendo', 'un', 'rápidamente', 'faula', 'grabación', 'encontró', 'partió', 'temorizado', 'público', 'el', 'perseguía', 'casas', 'elabas']
# Fábula 4 — Top 20 palabras clave:
# ['razón', 'puso', 'presencia', 'morder', 'mismo', 'mayores', 'le', 'había', 'gente', 'fanfarrones', 'delatan', 'defectos', 'cercana', 'can', 'campanilla', 'amo', 'lo', 'llamó', 'honor', 'encontraba']
# Fábula 5 — Top 20 palabras clave:
# ['reflejo', 'ajeno', 'río', 'propio', 'perro', 'trozo', 'pedazo', 'carne', 'vadiaba', 'llevando', 'este', 'soltó', 'llevó', 'codíciese', 'agua', 'pero', 'sabroso', 'creyó', 'adquirido', 'supuesto']
# Fábula 6 — Top 20 palabras clave:
# ['reflejo', 'perro', 'carne', 'río', 'trozo', 'pedazo', 'propio', 'ajeno', 'mayor', 'supuesto', 'pues', 'rebatar', 'llevando', 'realidad', 'deseando', 'corriente', 'bienajeno', 'esfuerzo', 'sabroso', 'pero']
# Fábula 7 — Top 20 palabras clave:
# ['lobo', 'si', 'tener', 'dijo', 'pero', 'lobos', 'vez', 'repartiese', 'común', 'un', 'cumplir', 'botín', 'poder', 'primero', 'magnífica', 'manera', 'casa', 'pusiera', 'confundido', 'leyes']
# Fábula 8 — Top 20 palabras clave:
# ['hueso', 'paga', 'pidió', 'grulla', 'logo', 'garcanta', 'enseguida', 'situación', 'hacepto', 'no', 'sano', 'convenida', 'hagas', 'dejan', 'entonces', 'cancelación', 'ello', 'partes', 'aniga', 'lobo']
# Fábula 9 — Top 20 palabras clave:
# ['cebada', 'carnicero', 'caballo', 'si', 'volvió', 'penetro', 'ocupado', 'se', 'viendole', 'cómo', 'corriendo', 'cogió', 'clientes', 'carnicería', 'lió', 'suceda', 'evitarlo', 'huir', 'inotando', 'introso']
# Fábula 10 — Top 20 palabras clave:
# ['morder', 'campanilla', 'razón', 'defectos', 'presencia', 'mismo', 'can', 'puso', 'solo', 'amo', 'advertirle', 'cercana', 'había', 'le', 'sonando', 'gente', 'mayores', 'delatan', 'perro', 'fanfarrones']

# %% [markdown]
# # **Ejercicio 5a y 5b:**

# %% [markdown]
# * #### **5a: Mediante el LLM que hayan seleccionado, generar un único enunciado que describa o resuma cada fábula.**
#
# * #### **5b: Mediante el LLM que hayan seleccionado, generar tres posibles enunciados diferentes relacionados con la historia de la fábula.**
#
# * #### **Sugerencia:** En realidad los dos incisos a y b se pueden obtener con un solo prompt que solicite la información y el formato correspondiente para cada una de estas partes. Por ejemplo, para cada fábula la salida puede ser un primer enunciado genérico que resume o describe dicha temática; seguido de tres enunciados, cada uno hablando sobre una situación o parte diferente de la fábula.

# %%
# Incluyan a continuación todas las celdas (de código o texto) que deseen...

from transformers import pipeline

# Cargar modelo (puedes usar otros como mistral, llama, etc.)
generator = pipeline("text-generation", model="gpt2")

filesL = [1, 4, 5, 6, 14, 22, 24, 25, 26, 27]
for i, f in enumerate(nText):
  prompt = f"""
            Lee la fábula y genera lo siguiente:

            1) Resumen de fábula.
            2) Tres enunciados de la fábula.

            Fábula: {f}
  """

  salida = generator(prompt, max_new_tokens=200)

  print(f"\nFábula {filesL[i]}:")
  print(salida[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 1:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: Tando se cuenta de que era perseguido por un lobo, un pequeño cordelito decidió refugiarse en un templo cercano. Lo llamó lobo y le dijo que si el sacrificador lo encontraba allí adentro, lo emolaría a su Dios. Mejor así replicó el cordero. Prefiero ser víctima para un Dios a tener que perecer en tus colmillos. Si sin remedio vamos a ser sacrificados, más nos vale que sea con el mayor honor.
#               3) Tando su Dios está por puede de Tábucuma de los que si la vida de las códigas del más, a las con el mayor.
#
#
# (Translation of the original)
#
#
# ¡Etamos muy eso lo quien dor la fábula.
#
# ¡Etamos muy eso lo quien dor la fábula. (Translation of the original) (Translation of the original) (Translation of the original) 1. Etamos muy eso lo quien dor la fábula.
#
#
# 1. Etamos muy eso lo quien dor la fábula. Etamos muy eso lo quien dor la fábula. 2. Etamos muy eso lo qu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 4:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: A un lobo que comía un hueso se le atragantó el hueso en la garganta y corría por todas partes en busca de auxilma. Encontro en su carrera una grulla y le pidió que le salvara de aquella situación y que enseguida le pagaría por ello. Hacepto la grulla e introdujo su cabeza en la boca del logo, sacando de la garcanta el hueso atravesado. Pidió entonces la cancelación de la paga convenida. Oye aniga, dijo el logo. No crees que es suficiente paga con haber sacado tu cabeza sana y salvada en mi boca? Nunca hagas favores a malvados, trascantes o corruptos, pues mucha paga tendrías si te dejan sano y salvo.
#
#
# I'm sorry, but you're not allowed to say that this is the first time you've ever gotten caught up in this shit.
#
# As I've said, I'm sorry, but you're not allowed to say that this is the first time you've ever gotten caught up in this shit.
#
# I'm sorry, but you're not allowed to say that this was the first time you've ever been caught up in this shit. Just in case you didn't get caught up in this shit, just in case you wanted to, you can ask your friends on reddit here.
#
# I'm sorry, but you're not allowed to say that this was the first time you've ever been caught up in this shit.
#
# Just in case you didn't get caught up in this shit, just in case you wanted to, you can ask your friends on reddit
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 5:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: Pasaba un lobo por un sembrado de cebada, pero como no era comida de su gusto, la dejó y siguió su camino. Encontró al rato a un caballo y le llevó al campo comentándole la gran cantidad de cebada que había hallado, pero que en vez de comerse la él, mejor se la había dejado, porque le agradaban más o ir el ruido de sus dientes al masticarla. Pero el caballo le repuso, amigo, si los lobos conmieran cebada, no hubieras preferido complacer a tus oídos si no a tu estómago. A todo malvado, aunque parezca actuar como bueno, no debe de creírsele.
#
#
# Máximo:
#
# Por que lo estábula, lo estábula, lo estábula, lo estábula, lo estábula. Por que lo estábula, lo estábula, lo estábula, lo estábula. Por que lo estábula, lo estábula, lo estábula, lo estábula. Por que lo estábula, lo estábula, lo estábula. Por que lo estábula, lo estábula, lo estábula. Por que lo estábula, lo estábula, lo estábula. Por que lo estábula, lo estábula, lo estábula. Por que lo está
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 6:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: Un lobo fue elegido rey entre sus congéneres y decretó una ley ordenando que lo que cada uno capturase en la casa, lo pusiera en común y lo repartiese por partes iguales entre todos. De esta manera, ya no tendría los lobos que devorarse unos a otros en épocas de hambre. Pero no hizole escucho un asno que estaba por ahí cerca y moviendo sus orejas le dijo, magnífica idea abrotado de tu corazón, pero ¿por qué se escondido todo tu botín en tu cueva, llevando a la comunidad y repártelo también como lo ha secretado? El lobo descubriarte confundido de Rogozulay. Si alguna vez llegas a tener poder de legislar, se el primero en cumplir tus propias leyes.
#
#
# The answer is "no". It is not a question of giving out the answer "yes" to certain things. It is a question of being prepared to give it out. It is a question of giving a way out of your dilemma. It is a question of giving your answer to certain things. It is a question of being prepared to give a way out of your dilemma. It is a question of giving your answer to certain things. It is a question of being prepared to give a way out of your dilemma. It is a question of giving your answer to certain things. It is a question of giving your answer to certain things. It is a question of being prepared to give a way out of your dilemma. It is a question of giving your answer to certain things.
#
# The answer is not a question of giving your answer to certain things. It is a question of giving your answer to certain
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 14:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: Infeliz, sé que no eres tú quien me está insultando sino el sitio en que te encuentras. Muy a menudo no es el valor sino la ocasión y el lugar quienes proveen el enfrentamiento arrogante ante los poderosos.
#               3) De fábula.
#               4) Desunciados de la fábula.
#
#
# The following is a list of the languages that are not spoken in English. The language spoken in Spanish and Portuguese is not necessarily the same as the languages spoken in English. The language spoken in Mandarin Chinese is the dialect of the Chinese language spoken in Hong Kong. It is not known whether the language spoken in Hong Kong is spoken in Spanish or in Portuguese.
#
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
#
# Chinese:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 22:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: Un perro de esos acostumbrados a comer huevos al ver una alméja, no lo pensó dos veces y creyendo que se trataba de un huevo, se la atragó inmediatamente. Descarradas luego sus entrañas se sintió muy mal y se dijo. Bien merecido lo tengo, por creer que todo lo que veo redondo son huevos. Nunca tomes un asunto sin antes reflexionar, para no entrar luego en extrañas dificultades. Fín de la faula. Esta grabación es del dominio público.
#             2) Bien una estas pudios y que hacermente pero los casa desde se luego.
#             3) Esta estas para la faula.
#               4) Esta estas pasando el faula.
#               5) Estas de la faula, con se luego o puede. Bien una estas pudios y que hacermente pero los casa desde se luego.
#                 6) Esta se hacermente una se muy de luego.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 24:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: Vadiaba un perro, un río, llevando en su hocico un sabroso pedazo de carne, vio su propio reflejo en el agua del río y creyó que aquel reflejo era, en realidad, otro perro, que llevaba un trozo de carne mayor que el suyo, y deseando adueñarse del pedazo ajeno, soltó el suyo para rebatar el trozo a su supuesto compadre. Pero el resultado fue que se quedó sin el propio y sin el ajeno. Este, porque no existía, sólo era un reflejo, y el otro, el verdadero, porque se lo llevó a la corriente. Nunca codíciese el bienajeno, pues puedes perder lo que ya has adquirido con tu esfuerzo.
#           1 ) Enfermente de bienajeno.
#             2) Enfermente de lo que tres enunciados de la fábula.            3) Enfermente de lo que tres enunciados de la fábula.
#             4) Enfermente de lo que tres enunciados de la fábula.           5) Enfermente de lo que tres enunciados de la fábula.
#            6) Enfermente de lo que tres enunciados de la fábula.            7) Enfermente de lo que
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 25:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: Penetro, un pero en una carnicería, inotando que el carnicero estaba muy ocupado con sus clientes, cogió introso de carne y se lió corriendo. Se volvió el carnicero, y viendole a huir, y sin No esperes a que suceda un accidente para pensar en cómo evitarlo.
#               3) El fin que no hay trabajo en la fábula y genera lo siguiente:
#
#
# La fábula de gente, el nuevo de los cosa y lo siguiente, de la fábula una cómo, y espere que se siente algunas de tres los cumbres o una cumbre.
#
#                4) El fin que no hay trabajo.
#
#                  5) El fin que no hay trabajo.
#
#
# Il fábula que se fuerzas como á la fábula de la fábula.
#
# La fábula que se fuerzas como
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Fábula 26:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: Había un perro que acostumbraba a morder sin razón. Le puso su amo una campanilla para advertirle a la gente de su presencia cercana, y el can sonando la campanilla se fue a sí mismo, los fanfarrones, solo delatan sus mayores defectos.
#
#
#
# 3) The second part of the statement shows the difference in the number of hours and the time of day. This can be seen in the photo of the left hand side. The right hand side shows that the same number of hours are actually not counted in this statement. The third part explains what is different from the first part. The third part explains how to use this time. The first part explains how to use this time.
#
#
# 3) The first part shows how to use this time. As for the second part, it explains how to use this time.
#
#
# 3) The second part shows how to use this time. As for the first part, it explains how to use this time.
#
#
# 3) The second part shows how to use this time. As for the first part, it explains how to use this time.
#
#
# 3) The third
#
# Fábula 27:
#
#             Lee la fábula y genera lo siguiente:
#
#             1) Resumen de fábula.
#             2) Tres enunciados de la fábula.
#
#             Fábula: El perro que perseguía al león. Un perro de casas se encontró con un león y partió en su persecución, pero el león se volvió rugiendo y el perro todo a temorizado, retrocedió rápidamente por elabas. Fínde la faula, esta grabación es del dominio público.

# %% [markdown]
# # **Ejercicio 6:**

# %% [markdown]
# * #### **Incluyan sus conclusiones de la actividad audio-a-texto:**
#
#
#
# None

# %% [markdown]
# # **Fin de la actividad LDA y LMM: audio-a-texto**
